# %% [markdown]
# # Auto Insurance Premiums Prediction
# ### By Samuel Mendez

# %% [markdown]
# ### Objective:
# Develop a model to predict the insurance premium for individual customers based on their demographic and history. This can help insurance companies accurately price their policies, provide personalized quotes, and understand the factors driving premium variations.

# %% [markdown]
# ### Data
# This data set was provided by Kaggle:
# https://www.kaggle.com/datasets/merishnasuwal/auto-insurance-churn-analysis-dataset?select=demographic.csv
# The provided data asset is relational and consists of four distinct data files.
#
# 1. address.csv: contains address information
#
# 2. customer.csv: contains customer information.
#
# 3. demographic.csv: contains demographic data
#
# 4. termination.csv: includes customer termination information.
#
# All data sets are linked using either ADDRESS_ID or INDIVIDUAL_ID. The ADDRESS_ID pertains to a specific postal service address, while the INDIVIDUAL_ID is unique to each individual. It is important to note that multiple customers may be assigned to the same address, and not all customers have demographic information available.
#
# The data set includes 1,536,673 unique addresses and 2,280,321 unique customers, of which 2,112,579 have demographic information. Additionally, 269,259 customers cancelled their policies within the previous year. Finally, the customer information in this data set is fictituous although it refers information from Texas.

# %%
#import packages

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
#load csv files

address = pd.read_csv("address.csv")
churn = pd.read_csv("autoinsurance_churn.csv")
customer = pd.read_csv("customer.csv")
demo = pd.read_csv("demographic.csv")
terminate = pd.read_csv("termination.csv")

# %% [markdown]
# ### Data at a Glance

# %%
address.head(5)
# Out:
#      ADDRESS_ID   LATITUDE  LONGITUDE                  STREET_ADDRESS    CITY  \
# 0  5.213011e+11  32.315803 -96.627896  8457 Wright Mountains Apt. 377   Ennis
# 1  5.213000e+11        NaN        NaN    082 Cline Mountains Apt. 353  Irving
# 2  5.213002e+11  32.806290 -96.779857                  457 John Mills  Dallas
# 3  5.213013e+11  32.825737 -96.939687             5726 Barnett Meadow  Irving
# 4  5.213010e+11  32.867192 -96.715552              050 Nicholas Views  Dallas
#
#   STATE  COUNTY
# 0    TX   Ellis
# 1    TX  Dallas
# 2    TX  Dallas
# 3    TX  Dallas
# 4    TX  Dallas

# %%
churn.head(5)
# Out:
#    individual_id    address_id  curr_ann_amt  days_tenure cust_orig_date  \
# 0   2.213000e+11  5.213000e+11    818.877997       1454.0     2018-12-09
# 1   2.213001e+11  5.213001e+11    974.199182       1795.0     2018-01-02
# 2   2.213007e+11  5.213002e+11    967.375112       4818.0     2009-09-23
# 3   2.213016e+11  5.213006e+11    992.409561        130.0     2022-07-25
# 4   2.213016e+11  5.213006e+11    784.633494       5896.0     2006-10-11
#
#    age_in_years date_of_birth   latitude  longitude           city state  \
# 0            44    1978-06-23  32.578829 -96.305006        Kaufman    TX
# 1            72    1950-05-30  32.732209 -97.000893  Grand Prairie    TX
# 2            55    1967-07-07  32.819777 -96.846938         Dallas    TX
# 3            53    1969-05-25  32.684065 -97.162180      Arlington    TX
# 4            50    1972-09-25  32.751398 -97.376745     Fort Worth    TX
#
#     county    income  has_children  length_of_residence marital_status  \
# 0  Kaufman   22500.0           1.0                 15.0        Married
# 1   Dallas   27500.0           0.0                  2.0         Single
# 2   Dallas   42500.0           0.0                 10.0        Married
# 3  Tarrant  125000.0           1.0                  6.0        Married
# 4  Tarrant   87500.0           1.0                  4.0        Married
#
#   home_market_value  home_owner  college_degree  good_credit acct_suspd_date  \
# 0     50000 - 74999         1.0             1.0          1.0             NaN
# 1     50000 - 74999         1.0             0.0          0.0             NaN
# 2     75000 - 99999         1.0             0.0          0.0             NaN
# 3   175000 - 199999         1.0             0.0          1.0      2021-12-22
# 4   225000 - 249999         1.0             1.0          1.0             NaN
#
#    Churn
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0

# %%
customer.head(5)
# Out:
#    INDIVIDUAL_ID    ADDRESS_ID  CURR_ANN_AMT  DAYS_TENURE CUST_ORIG_DATE  \
# 0   2.213000e+11  5.213000e+11    818.877997       1454.0     2018-12-09
# 1   2.213001e+11  5.213001e+11    974.199182       1795.0     2018-01-02
# 2   2.213007e+11  5.213002e+11    967.375112       4818.0     2009-09-23
# 3   2.213016e+11  5.213006e+11    992.409561        130.0     2022-07-25
# 4   2.213016e+11  5.213006e+11    784.633494       5896.0     2006-10-11
#
#    AGE_IN_YEARS DATE_OF_BIRTH SOCIAL_SECURITY_NUMBER
# 0        44.474    1978-06-23            608-XX-7640
# 1        72.559    1950-05-30            342-XX-6908
# 2        55.444    1967-07-07            240-XX-9224
# 3        53.558    1969-05-25            775-XX-6249
# 4        50.220    1972-09-25            629-XX-7298

# %%
demo.head(5)
# Out:
#    INDIVIDUAL_ID      INCOME  HAS_CHILDREN  LENGTH_OF_RESIDENCE  \
# 0   2.213028e+11  125000.000           1.0                  8.0
# 1   2.213032e+11   42500.000           0.0                  0.0
# 2   2.213032e+11   27500.000           0.0                 15.0
# 3   2.213032e+11   80372.176           0.0                  0.0
# 4   2.213032e+11  125000.000           0.0                  0.0
#
#   MARITAL_STATUS HOME_MARKET_VALUE  HOME_OWNER  COLLEGE_DEGREE  GOOD_CREDIT
# 0         Single   300000 - 349999           1               1            1
# 1         Single               NaN           0               0            0
# 2        Married     75000 - 99999           1               0            1
# 3            NaN      1000 - 24999           1               0            0
# 4            NaN               NaN           0               0            1

# %%
terminate.head(5)
# Out:
#    INDIVIDUAL_ID ACCT_SUSPD_DATE
# 0   2.213026e+11      2022-10-09
# 1   2.213028e+11      2022-04-24
# 2   2.213027e+11      2022-05-21
# 3   2.213002e+11      2022-04-27
# 4   2.213026e+11      2022-09-16

# %% [markdown]
# ### Cleaning and Preparing Data

# %%
# change column names to lowercase

dfs = [address, churn, customer, demo, terminate]

for df in dfs:
    df.columns = df.columns.str.lower()

# %%
# check for missing values values
dfs_name = {'address':address, 'churn':churn, 'customer':customer, 'demo':demo, 'terminate':terminate}

for df_name, df in dfs_name.items():
    print(f"Missing values in {df_name}:")
    print(df.isnull().sum())
    print('\n')
# Out:
# Missing values in address:
# address_id             0
# latitude          129961
# longitude         129961
# street_address         0
# city               15434
# state                  0
# county             15434
# dtype: int64
#
#
# Missing values in churn:
# individual_id                0
# address_id                   0
# curr_ann_amt                 0
# days_tenure                  0
# cust_orig_date               0
# age_in_years                 0
# date_of_birth                0
# latitude                253719
# longitude               253719
# city                     12067
# state                        0
# county                   12067
# income                       0
# has_children                 0
# length_of_residence          0
# marital_status               0
# home_market_value        92286
# home_owner                   0
# college_degree               0
# good_credit                  0
# acct_suspd_date        1487453
# churn                        0
# dtype: int64
#
#
# Missing values in customer:
# individual_id                  1
# address_id                     1
# curr_ann_amt                   0
# days_tenure                    0
# cust_orig_date                 0
# age_in_years              167766
# date_of_birth                  0
# social_security_number         0
# dtype: int64
#
#
# Missing values in demo:
# individual_id               0
# income                      0
# has_children                0
# length_of_residence         0
# marital_status         431648
# home_market_value      190205
# home_owner                  0
# college_degree              0
# good_credit                 0
# dtype: int64
#
#
# Missing values in terminate:
# individual_id      0
# acct_suspd_date    0
# dtype: int64

# %% [markdown]
# There are many missing values in each data frame. Latitude and longitude have a high frequence of mising values. This might not be to critical for the analysis we will do later. Account suspention date also has a lot of missing values which could imply that all these accounts are still active. There are missing values in age but that can be populated since we know the customers date of birth in `customer` df. Since most data frames have a `customer_id`, it would be useful to use it as our index.

# %%
# check row with missing individual_id in customer df

customer[customer['individual_id'].isnull()]

# remove this row to convert dtype of individual_id to int64 to use as index for merged dfs

customer = customer.dropna(subset = ['individual_id'])

# %%
# change individual_id from float64 to int64

dfs_iid = [terminate, demo, customer, churn]

for df in dfs_iid:
    df['individual_id'] = df['individual_id'].astype('int64')
# Out:
# C:\Users\mende\AppData\Local\Temp\ipykernel_10620\148917070.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['individual_id'] = df['individual_id'].astype('int64')

# %% [markdown]
# Before we continue analyzing our data, merging our dataframes into one dataframe will allows us to purposefully fill missing values, engineer valuable features, remove unnecessary data, etc. We will leave the `terminate` and `demo` dfs out since this information is captured in the `churn` df.

# %%
# merge customer and address df on address_id
ctmr_add = customer.merge(address, on = 'address_id')

ctmr_add.head()
# Out:
#    individual_id    address_id  curr_ann_amt  days_tenure cust_orig_date  \
# 0   221300017872  5.213000e+11    818.877997       1454.0     2018-12-09
# 1   221300134410  5.213001e+11    974.199182       1795.0     2018-01-02
# 2   221300134409  5.213001e+11    670.603798       1097.0     2019-12-01
# 3   221300673028  5.213002e+11    967.375112       4818.0     2009-09-23
# 4   221300673027  5.213002e+11    923.707801       4539.0     2010-06-29
#
#    age_in_years date_of_birth social_security_number   latitude  longitude  \
# 0        44.474    1978-06-23            608-XX-7640  32.578829 -96.305006
# 1        72.559    1950-05-30            342-XX-6908  32.732209 -97.000893
# 2        51.305    1971-08-26            418-XX-4007  32.732209 -97.000893
# 3        55.444    1967-07-07            240-XX-9224  32.819777 -96.846938
# 4        38.639    1984-04-22            175-XX-7906  32.819777 -96.846938
#
#               street_address           city state   county
# 0       52966 Welch Crescent        Kaufman    TX  Kaufman
# 1       46887 Lawrence Green  Grand Prairie    TX   Dallas
# 2       46887 Lawrence Green  Grand Prairie    TX   Dallas
# 3  787 Daniel Mews Suite 806         Dallas    TX   Dallas
# 4  787 Daniel Mews Suite 806         Dallas    TX   Dallas

# %%
# merge the churn df

cust_data = pd.concat([ctmr_add, churn], axis = 1)

# drop duplicate column names NOTE: this is ok since columns contained identical information

cust_data = cust_data.loc[:, ~ cust_data.columns.duplicated()]

cust_data.head()
# Out:
#    individual_id    address_id  curr_ann_amt  days_tenure cust_orig_date  \
# 0   221300017872  5.213000e+11    818.877997       1454.0     2018-12-09
# 1   221300134410  5.213001e+11    974.199182       1795.0     2018-01-02
# 2   221300134409  5.213001e+11    670.603798       1097.0     2019-12-01
# 3   221300673028  5.213002e+11    967.375112       4818.0     2009-09-23
# 4   221300673027  5.213002e+11    923.707801       4539.0     2010-06-29
#
#    age_in_years date_of_birth social_security_number   latitude  longitude  \
# 0        44.474    1978-06-23            608-XX-7640  32.578829 -96.305006
# 1        72.559    1950-05-30            342-XX-6908  32.732209 -97.000893
# 2        51.305    1971-08-26            418-XX-4007  32.732209 -97.000893
# 3        55.444    1967-07-07            240-XX-9224  32.819777 -96.846938
# 4        38.639    1984-04-22            175-XX-7906  32.819777 -96.846938
#
#               street_address           city state   county    income  \
# 0       52966 Welch Crescent        Kaufman    TX  Kaufman   22500.0
# 1       46887 Lawrence Green  Grand Prairie    TX   Dallas   27500.0
# 2       46887 Lawrence Green  Grand Prairie    TX   Dallas   42500.0
# 3  787 Daniel Mews Suite 806         Dallas    TX   Dallas  125000.0
# 4  787 Daniel Mews Suite 806         Dallas    TX   Dallas   87500.0
#
#    has_children  length_of_residence marital_status home_market_value  \
# 0           1.0                 15.0        Married     50000 - 74999
# 1           0.0                  2.0         Single     50000 - 74999
# 2           0.0                 10.0        Married     75000 - 99999
# 3           1.0                  6.0        Married   175000 - 199999
# 4           1.0                  4.0        Married   225000 - 249999
#
#    home_owner  college_degree  good_credit acct_suspd_date  churn
# 0         1.0             1.0          1.0             NaN    0.0
# 1         1.0             0.0          0.0             NaN    0.0
# 2         1.0             0.0          0.0             NaN    0.0
# 3         1.0             0.0          1.0      2021-12-22    1.0
# 4         1.0             1.0          1.0             NaN    0.0

# %%
cust_data.isnull().sum()
# Out:
# individual_id                   0
# address_id                      0
# curr_ann_amt                    0
# days_tenure                     0
# cust_orig_date                  0
# age_in_years               167765
# date_of_birth                   0
# social_security_number          0
# latitude                   471491
# longitude                  471491
# street_address                  0
# city                        17008
# state                           0
# county                      17008
# income                     599411
# has_children               599411
# length_of_residence        599411
# marital_status             599411
# home_market_value            6959
# home_owner                 599411
# college_degree             599411
# good_credit                599411
# acct_suspd_date           2086864
# churn                      599411
# dtype: int64

# %%
cust_data[cust_data['county'].isnull()].head()
# Out:
#       individual_id    address_id  curr_ann_amt  days_tenure cust_orig_date  \
# 1129   221303291761  5.213015e+11    655.653460       1960.0     2017-07-21
# 2891   221302753150  5.213010e+11   1038.839760       6291.0     2005-09-11
# 2892   221302753149  5.213010e+11   1248.270650         87.0     2022-09-06
# 4527   221302754491  5.213010e+11    738.078569       2704.0     2015-07-08
# 4953   221303302608  5.213015e+11    935.916115       1839.0     2017-11-19
#
#       age_in_years date_of_birth social_security_number   latitude  longitude  \
# 1129        39.387    1983-07-24            610-XX-3821        NaN        NaN
# 2891        47.220    1975-09-25            552-XX-1989  32.760158 -96.803220
# 2892        41.725    1981-03-22            717-XX-6244  32.760158 -96.803220
# 4527        67.305    1955-08-30            188-XX-1002  32.651159 -97.372223
# 4953        68.307    1954-08-29            438-XX-5372        NaN        NaN
#
#                    street_address city state county   income  has_children  \
# 1129             339 Nichols View  NaN    TX    NaN  62500.0           1.0
# 2891  83756 Gabriel Flat Apt. 395  NaN    TX    NaN  27500.0           0.0
# 2892  83756 Gabriel Flat Apt. 395  NaN    TX    NaN  62500.0           0.0
# 4527  5748 Jackson Plain Apt. 177  NaN    TX    NaN  27500.0           1.0
# 4953    332 Morris Pass Suite 720  NaN    TX    NaN  87500.0           1.0
#
#       length_of_residence marital_status home_market_value  home_owner  \
# 1129                 10.0        Married      1000 - 24999         1.0
# 2891                  4.0         Single   250000 - 274999         0.0
# 2892                  6.0         Single   400000 - 449999         1.0
# 4527                 15.0         Single     75000 - 99999         1.0
# 4953                  5.0        Married   125000 - 149999         1.0
#
#       college_degree  good_credit acct_suspd_date  churn
# 1129             0.0          1.0             NaN    0.0
# 2891             0.0          1.0             NaN    0.0
# 2892             0.0          1.0             NaN    0.0
# 4527             0.0          1.0             NaN    0.0
# 4953             1.0          1.0             NaN    0.0

# %% [markdown]
# Many observations that are missing values in `city` and `county` have latitude and longitude information. We can use this information to fill the missing values and minimize the amount of observations we have to drop because of missing values.

# %%
# fill missing value in home_market_value with median of county

mode_home_val = cust_data.groupby('city')['home_market_value'].transform(lambda x: x.mode()[0])

cust_data['home_market_value'] = cust_data['home_market_value'].fillna(mode_home_val)

# %% [markdown]
# ### Data Exploration

# %%
cust_data.shape
# Out:
# (2280320, 24)

# %%
cust_data.isnull().sum()
# Out:
# individual_id                   0
# address_id                      0
# curr_ann_amt                    0
# days_tenure                     0
# cust_orig_date                  0
# age_in_years               167765
# date_of_birth                   0
# social_security_number          0
# latitude                   471491
# longitude                  471491
# street_address                  0
# city                        17008
# state                           0
# county                      17008
# income                     599411
# has_children               599411
# length_of_residence        599411
# marital_status             599411
# home_market_value            6959
# home_owner                 599411
# college_degree             599411
# good_credit                599411
# acct_suspd_date           2086864
# churn                      599411
# dtype: int64

# %%
# Insurance policy counts by County and City
pd.set_option("display.max_rows", None)

print(cust_data['county'].value_counts())
print('\n')
print(cust_data['city'].value_counts())
# Out:
# Dallas      865587
# Tarrant     658923
# Collin      291553
# Denton      248770
# Ellis        57850
# Kaufman      41896
# Parker       31827
# Rockwall     30634
# Johnson      30616
# Hunt          2273
# Cooke         1994
# Navarro        743
# Grayson        552
# Hill            94
# Name: county, dtype: int64
#
#
# Dallas                   435836
# Fort Worth               303494
# Arlington                134094
# Plano                    110257
# Garland                   82254
# Irving                    73577
# Grand Prairie             58530
# Mckinney                  54700
# Mesquite                  50804
# Denton                    46573
# Frisco                    46441
# Carrollton                45631
# Lewisville                39427
# Richardson                38569
# Keller                    35602
# Allen                     35409
# North Richland Hills      25080
# Flower Mound              24752
# Burleson                  23816
# Euless                    23133
# Mansfield                 22966
# Rockwall                  22579
# Rowlett                   22056
# Bedford                   20007
# Desoto                    19948
# Weatherford               18847
# The Colony                18762
# Wylie                     18533
# Grapevine                 18047
# Cedar Hill                17905
# Hurst                     16731
# Waxahachie                16501
# Coppell                   15643
# Lancaster                 14945
# Duncanville               14573
# Red Oak                   14509
# Little Elm                13678
# Forney                    13127
# Terrell                   11490
# Midlothian                11412
# Haltom City               11182
# Roanoke                   11153
# Azle                      11119
# Southlake                 10090
# Colleyville                9610
# Ennis                      8982
# Crowley                    8969
# Aubrey                     8803
# Royse City                 8055
# Sachse                     7946
# Balch Springs              7846
# Springtown                 7367
# Kaufman                    7284
# Argyle                     7120
# Joshua                     6800
# Seagoville                 6322
# Kemp                       6248
# Haslet                     5752
# Aledo                      5613
# Princeton                  5389
# Addison                    5332
# Sanger                     5291
# Justin                     5026
# Lake Dallas                4431
# Anna                       4262
# Prosper                    3964
# Farmersville               3195
# Celina                     3045
# Krum                       2947
# Kennedale                  2939
# Pilot Point                2523
# Ferris                     2320
# Melissa                    2308
# Caddo Mills                2273
# Sunnyvale                  1994
# Crandall                   1950
# Valley View                1806
# Scurry                     1797
# Palmer                     1758
# Ponder                     1698
# Nevada                     1534
# Lavon                      1299
# Hutchins                   1284
# Blue Ridge                 1236
# Wilmer                     1159
# Italy                      1090
# Maypearl                    675
# Rice                        625
# Tioga                       552
# Milford                     446
# Era                         188
# Forreston                   157
# Chatfield                   118
# Naval Air Station Jrb       108
# Mertens                      94
# Name: city, dtype: int64

# %% [markdown]
# ## Notes:
# * All dfs except address contain individual_id. We can merge on this column. individual_id would be a good index for a merged df.
# * Address, churn and customer contain an address_id.

# %% [markdown]
# ## To do:
# * [complete] in churn dataset change the Churn column name to lowercase
# * [complete] in address+customer+demo+terminate dataset, change colnames to lowercase
# * [complete] merge dfs to a single df
# * use `latitude` and `longitude` to fill missing value in `city` and `county`
# * analyze dfs, clean, remove/replace NAs
